# %%
import numpy as np
import scipy as sp
import pandas as pd
import rpy2 as rp
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter
import os 
import rpy2.robjects as ro
import pickle
from collections import Counter


# import R's "flowCore" package
utils = importr('flowCore')
os.chdir('../')

# %%
##### list fcs files #####
cytof_files = pd.read_csv("Bioheart_combined_metadata.csv")
print(cytof_files)
fn = [os.path.join(os.getcwd(),f) for f in cytof_files.file_name]
fn
# Out:
#      sample_id  Gensini_bin                file_name   data
# 0           87            1   Bioheart_sample_87.fcs  train
# 1           88            1   Bioheart_sample_88.fcs  train
# 2           89            1   Bioheart_sample_89.fcs  train
# 3           92            1   Bioheart_sample_92.fcs  train
# 4           96            1   Bioheart_sample_96.fcs  train
# ..         ...          ...                      ...    ...
# 164        605            0  Bioheart_sample_605.fcs   test
# 165        460            0  Bioheart_sample_460.fcs   test
# 166        802            1  Bioheart_sample_802.fcs   test
# 167        668            0  Bioheart_sample_668.fcs   test
# 168        556            0  Bioheart_sample_556.fcs   test
#
# [169 rows x 4 columns]
# ['/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_87.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_88.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_89.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_92.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_96.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_97.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_103.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_152.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_154.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_167.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_169.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_171.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_173.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_204.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_208.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_211.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_213.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_214.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_215.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_223.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_224.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_229.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_230.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_231.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_232.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_236.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_241.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_245.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_246.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_250.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_251.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_255.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_257.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_258.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_259.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_260.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_264.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_270.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_276.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_288.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_293.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_295.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_297.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_307.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_322.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_334.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_342.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_347.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_358.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_360.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_364.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_373.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_380.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_390.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_406.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_409.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_413.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_428.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_437.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_440.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_442.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_446.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_465.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_501.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_520.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_525.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_528.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_551.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_586.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_587.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_591.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_603.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_608.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_621.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_625.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_628.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_633.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_674.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_679.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_702.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_710.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_711.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_715.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_717.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_719.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_723.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_732.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_737.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_739.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_740.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_747.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_750.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_761.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_767.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_768.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_770.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_771.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_774.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_776.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_777.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_791.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_801.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_804.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_805.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_867.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_868.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_872.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_880.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_894.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_940.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_941.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_271.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_206.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_567.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_313.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_667.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_205.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_332.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_86.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_209.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_508.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_274.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_524.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_101.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_155.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_616.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_677.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_795.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_874.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_794.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_780.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_210.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_720.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_218.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_736.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_365.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_944.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_262.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_387.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_93.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_233.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_90.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_516.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_965.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_222.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_745.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_596.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_505.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_349.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_707.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_693.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_165.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_143.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_763.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_863.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_317.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_248.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_781.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_725.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_304.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_527.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_405.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_778.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_634.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_605.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_460.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_802.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_668.fcs',
#  '/Users/elijahwillie/Documents/PhD/DeepLearning_CyTOF/Bioheart_combined/Bioheart_sample_556.fcs']

# %%
##### read fcs file using the flowCore R package #####
# flowCore is a very well maintained R package for reading and analyzing fcs files
# Many of the fcs file related packages in python are a little buggy to use
# Therefore, it is worth the trouble to read the fcs files using R 

r = rp.robjects.r
expr_list = []
for i in range(0,len(fn)):
    fn_i = fn[i]
    r_code = ("library(flowCore);"+
          "library(MetaCyto);"+
          "fn = '"+ fn_i+ "'; "+
          "fcs = read.FCS(fn,truncate_max_range = FALSE);"+
          "expr = fcs@exprs;"+
          "markers = markerFinder(fcs);"+ 
          "colnames(expr) = markers;"+
          "expr = as.data.frame(expr);"
         # subsample 10,000 cells

         "expr = expr[sample(1:nrow(expr),10000,replace = TRUE), ];" +
             "return(as.data.frame(expr));")
    expr =  r(r_code)
    expr_list.append(expr)

# %%
expr_list[2]
# Out:
# <rpy2.robjects.vectors.DataFrame object at 0x12f5fd1d0> [19]
# R classes: ('data.frame',)
# [FloatSexp..., FloatSexp..., FloatSexp..., FloatSexp..., ..., FloatSexp..., FloatSexp..., FloatSexp..., FloatSexp...]
#   HLA_DR: <class 'rpy2.robjects.vectors.FloatVector'>
#   <rpy2.robjects.vectors.FloatVector object at 0x10f33f250> [14]
# R classes: ('numeric',)
# [0.000000, 1.077275, 1.858683, 1.504390, ..., 2.660940, 64.054016, 1.581026, 0.000000]
#   CD3: <class 'rpy2.robjects.vectors.FloatVector'>
#   <rpy2.robjects.vectors.FloatVector object at 0x11064e390> [14]
# R classes: ('numeric',)
# [80.998055, 0.000000, 328.272766, 383.252319, ..., 1.363354, 20.610851, 175.718628, 159.044159]
#   CD4: <class 'rpy2.robjects.vectors.FloatVector'>
#   <rpy2.robjects.vectors.FloatVector object at 0x11062ec10> [14]
# R classes: ('numeric',)
# [44.891235, 0.468571, 63.528400, 151.527740, ..., 4.308849, 15.391182, 69.520859, 69.141266]
#   CD8A: <class 'rpy2.robjects.vectors.FloatVector'>
#   <rpy2.robjects.vectors.FloatVector object at 0x11062efd0> [14]
# R classes: ('numeric',)
# [0.000000, 1.750629, 0.000000, 0.000000, ..., 0.000000, 0.000000, 0.000000, 0.000000]
# ...
#   CD127: <class 'rpy2.robjects.vectors.FloatVector'>
#   <rpy2.robjects.vectors.FloatVector object at 0x11062d890> [14]
# R classes: ('numeric',)
# [1.409576, 3.910381, 0.000000, 2.238157, ..., 0.000000, 77.641983, 0.000000, 0.000000]
#   FOXP3: <class 'rpy2.robjects.vectors.FloatVector'>
#   <rpy2.robjects.vectors.FloatVector object at 0x11062fc50> [14]
# R classes: ('numeric',)
# [0.129048, 0.000000, 0.000000, 0.000000, ..., 0.950135, 0.000000, 0.000000, 0.000000]
#   CD27: <class 'rpy2.robjects.vectors.FloatVector'>
#   <rpy2.robjects.vectors.FloatVector object at 0x11062f650> [14]
# R classes: ('numeric',)
# [0.577319, 0.000000, 2.107844, 6.196556, ..., 0.000000, 11.569795, 0.000000, 4.394193]
#   KLRG1: <class 'rpy2.robjects.vectors.FloatVector'>
#   <rpy2.robjects.vectors.FloatVector object at 0x11062ea90> [14]
# R classes: ('numeric',)
# [0.925188, 2.517735, 0.000000, 0.000000, ..., 0.000000, 3.288527, 0.537952, 2.552474]

# %%
markers = []
for i in range(len(expr_list)):
#     expr_list[i].colna = expr_list[i].columns.str.replace(' ', '-')
    markers.extend(expr_list[i].colnames)

markers = Counter(markers)
markers = [k for k, c in markers.items() if c == 169]
print(markers)

for i in range(0,len(expr_list)):
    t1 = expr_list[i] 
    with localconverter(ro.default_converter + pandas2ri.converter):
        t1 = ro.conversion.rpy2py(t1)
    expr_list[i] = t1.loc[:,markers]
# Out:
# ['HLA_DR', 'CD3', 'CD4', 'CD8A', 'CD25', 'CD127', 'FOXP3', 'CD27', 'KLRG1', 'CD56', 'CD45RO', 'CD45RA', 'CD192_CCR2', 'CD194_CCR4', 'CD196_CCR6', 'CD39', 'CD38', 'KI67', 'CD183_CXCR3', 'CCR7', 'CD19', 'CD20', 'IGD', 'CD14', 'CD304', 'CD141', 'CD1C_PE']

# %%
len(markers)
# Out:
# 27

# %%
##### transform and format into numpy array
def arcsinh(x):
    return(np.arcsinh(x/5))

coln = expr_list[0].columns
for i in range(len(expr_list)):
    t1 = expr_list[i]
    t1 = t1.apply(arcsinh)
    t1 = t1.values
    shape1 = list(t1.shape)+[1]
    t1 = t1.reshape(shape1)
    expr_list[i] = t1
    
expr_list = np.stack(expr_list)
print("The dimenstion of the data is: ", expr_list.shape)
# Out:
# The dimenstion of the data is:  (169, 10000, 27, 1)

# %%
coln
# Out:
# Index(['HLA_DR', 'CD3', 'CD4', 'CD8A', 'CD25', 'CD127', 'FOXP3', 'CD27',
#        'KLRG1', 'CD56', 'CD45RO', 'CD45RA', 'CD192_CCR2', 'CD194_CCR4',
#        'CD196_CCR6', 'CD39', 'CD38', 'KI67', 'CD183_CXCR3', 'CCR7', 'CD19',
#        'CD20', 'IGD', 'CD14', 'CD304', 'CD141', 'CD1C_PE'],
#       dtype='object')

# %%
allData = {"cytof_files":cytof_files, 
            "expr_list" : expr_list,
            "marker_names" : coln}

with open("DL_CyTOF/Bioheart_combined_allData.obj", "wb") as f:
    pickle.dump(allData, f)
